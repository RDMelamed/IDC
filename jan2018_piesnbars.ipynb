# %% [markdown]
# ## Summary of donations
# Updated spreadsheet is on the google drive, sheet "jan6_cleaned" had the most recent edits, with all of the work from the sheet "since_jan2016_jul24" incorporated (we could remove that one).
#
# Here are the updated pie charts of fraction of donations from each industry (legend is on the spreadsheet) (please excuse the next line of code):

# %%
from IPython.display import Image ; Image(filename='pngs/summary_bar_jan9.png',width=700)

# %%
Image(filename='pngs/idc_cand_pies_jan18.png',width=700)
