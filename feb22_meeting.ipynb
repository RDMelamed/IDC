# %% [markdown]
# Updated to include filings from Jan 2018, and to include all senate filers. So, this analysis should be less biased about the IDC donors, though category annotation for donors to the IDC is still much more complete than donors to other candidates.

# %%
from IPython.display import Image ; Image(filename='pngs/feb22_barsummary.png',width=800)

# %% [markdown]
# How do the top categories vary by recipient? I sorted recipients by total dollars from each category.  Note that the scales of dollars vary widely between categories (see the "by industry" plot above).

# %%
Image(filename='pngs/feb22_category.png',width=600)

# %% [markdown]
# Similarly, I found the donors who spent the most, total (so this is not biased either way about the IDC), and I again sorted recipients by total dollars from each category.

# %%
Image(filename='pngs/feb22_donors.png',width=500)

# %% [markdown]
# Combining the 2 things, who are the top donors from each industry, and how much do they give to each party?

# %%
Image(filename='pngs/feb22_category_top_donors.png',width=600)
